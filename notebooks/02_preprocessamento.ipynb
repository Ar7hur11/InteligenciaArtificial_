# %% [markdown]
# # 02 — Pré-processamento
# Organizar e preparar as imagens para o YOLO.

# %%
# Verifique se o data.yaml está correto
import yaml
with open('../data.yaml') as f:
    cfg = yaml.safe_load(f)
print(cfg)

# %%
# TODO: adicionar aqui o código de split treino/val/teste
# e qualquer redimensionamento ou augmentation necessário
