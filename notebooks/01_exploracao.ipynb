# %% [markdown]
# # 01 — Exploração do Dataset
# Entendendo os dados antes de qualquer coisa.

# %%
import sys
sys.path.append('../src')
from data_loader import inspecionar_dataset, mostrar_amostras
from pathlib import Path

inspecionar_dataset(Path('../data/raw'))

# %%
mostrar_amostras(Path('../data/raw'), n=6)
